# %%
from glob import glob
import json
import pandas as pd

files = glob('./output/experiments_number_hidden_neurons/number_hidden_neurons_*.json')

all_dicts = []

for file in files:
    with open(file, "r") as f:
        data = json.load(f)
        all_dicts.append(data)

df = pd.DataFrame(all_dicts)
df = df.fillna(1)

df
# Out:
#    epochs  training_accuracy  test_accuracy          time  \
# 0      30           0.964286      68.330389   2263.509649
# 1      30           0.928571      47.835689   2643.530847
# 2      30           0.928571      51.678445   2822.504848
# 3      30           0.964286      60.821555   4254.402693
# 4      30           0.964286      65.415194   1777.914918
# 5      30           1.000000      52.782686   5656.773139
# 6      30           0.964286      59.319788   2648.201651
# 7      30           0.964286      46.466431   3179.290111
# 8      30           0.964286      51.634276  17533.443535
# 9      30           0.964286      49.160777   3514.291313
#
#    number_hidden_neurons
# 0                   1000
# 1                   3500
# 2                   4000
# 3                   2000
# 4                    500
# 5                   2500
# 6                   1500
# 7                   4500
# 8                   3000
# 9                   5000

# %%
import matplotlib.pyplot as plt

x = df["number_hidden_neurons"]
test_acc = df["test_accuracy"]
time = df["time"]

fig, axes = plt.subplots(1, 2, figsize=(12, 4))  # 1 row, 2 columns

axes[0].scatter(x, test_acc, marker='o', color='blue')
axes[0].set_title("Test Accuracy vs Number hidden layer")
axes[0].set_xlabel("Number hidden layer")
axes[0].set_ylabel("Test Accuracy")

axes[1].scatter(x, time, marker='^', color='green')
axes[1].set_title("Time vs Number hidden layer")
axes[1].set_xlabel("Number hidden layer")
axes[1].set_ylabel("Time (s)")

plt.tight_layout()
plt.show()

# %%
df["time"].sum() / 60
# Out:
# 771.5643784
